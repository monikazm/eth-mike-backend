# %%
# import
from matplotlib import pyplot as plt
import pandas as pd

# %%
file = pd.read_excel("KB_mike3.xlsx")
print(file)
# Out:
#      B FDM  K FDM  B tacho  K tacho  B FOAW  K FOAW
# 0   0.0000   0.40   0.0000     0.45  0.0000    0.30
# 1   0.0002   0.50   0.0002     0.60  0.0002    0.30
# 2   0.0004   0.50   0.0004     0.55  0.0004    0.25
# 3   0.0006   0.45   0.0006     0.50  0.0006    0.20
# 4   0.0008   0.30   0.0008     0.45  0.0008    0.15
# 5   0.0010   0.30   0.0010     0.40  0.0010    0.00
# 6   0.0012   0.20   0.0012     0.30     NaN     NaN
# 7   0.0014   0.20      NaN      NaN     NaN     NaN
# 8   0.0016   0.20      NaN      NaN     NaN     NaN
# 9   0.0018   0.15      NaN      NaN     NaN     NaN
# 10  0.0020   0.10      NaN      NaN     NaN     NaN
# 11  0.0022   0.00      NaN      NaN     NaN     NaN

# %%
# extract from csv
b_fdm = file["B FDM"]
k_fdm = file["K FDM"]
b_tacho = file["B tacho"]
k_tacho = file["K tacho"]
b_foaw = file["B FOAW"]
k_foaw = file["K FOAW"]

# %%
# plotting
plt.scatter(b_fdm,k_fdm)
plt.plot(b_fdm,k_fdm,label='FDM')

plt.scatter(b_tacho,k_tacho)
plt.plot(b_tacho,k_tacho,label='Tacho')

plt.scatter(b_foaw,k_foaw)
plt.plot(b_foaw,k_foaw,label='FOAW')

plt.legend()
plt.xlabel('B [(Nm*s)/deg]')
plt.ylabel('K [Nm/deg]')
plt.title('MIKE 3 KB-Plot')
plt.savefig("Mike3_KB_Plot.pdf")
plt.show()
